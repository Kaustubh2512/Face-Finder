# %% [markdown]
# # 👤 Face Finder AI - 🚀 High-Speed Event Edition
#
# This edition is optimized for speed, allowing you to process thousands of event photos using **GPU Acceleration**.
#
# ### 🎯 The Workflow:
# 1.  **Mount Drive**: Connect your Google Drive.
# 2.  **GPU Setup**: Enable GPU in Colab (`Runtime > Change runtime type > T4 GPU`).
# 3.  **Process**: Scan event photos and auto-sort them into folders per person.
# 4.  **Share**: Share the `per_person` folder with your group!

# %% [markdown]
# ### 1️⃣ Step 1: Connect your Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### 2️⃣ Step 2: Install High-Performance AI Libraries

# %%
# %cd /content
# !rm -rf Face-Finder
# !git clone https://github.com/0xYuvi/Face-Finder.git
# %cd Face-Finder
# !pip install -r requirements.txt
# !pip install onnxruntime-gpu

# %% [markdown]
# ### 3️⃣ Step 3: Configure Paths

# %%
# --- SETTINGS ---
KNOWN_FACES = "/content/drive/MyDrive/Face_Finder_data/Known"
EVENT_PHOTOS = "/content/drive/MyDrive/Face_Finder_data/Harishchandra gad trek "
OUTPUT_DIR = "/content/drive/MyDrive/Face_Finder_data/Output"

# Performance Tweaks
FAST_MODE = True
DET_SIZE = 320 if FAST_MODE else 640

# %% [markdown]
# ### 4️⃣ Step 4: Run High-Speed Processing

# %%
# !python face_finder1.py \
    --known "$KNOWN_FACES" \
    --photos "$EVENT_PHOTOS" \
    --output "$OUTPUT_DIR" \
    --det-size $DET_SIZE \
    --use-gpu

# %% [markdown]
# ### 📂 How to Share with the Group:
# 1. Open your Google Drive.
# 2. Find the folder: `/Output/per_person/`.
# 3. **Right-click > Share** this folder with your group using a link.
# 4. Each person can now enter the folder with their name and download all their photos at once!
